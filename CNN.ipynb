# %%
import numpy as np
import pandas as pd
import random
import io
import os
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import time
from tqdm import tqdm
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
from sklearn.metrics import roc_auc_score,cohen_kappa_score,matthews_corrcoef
from sklearn.model_selection import train_test_split
from IPython.display import Image,display,clear_output
import pywt

import tensorflow as tf
from keras.utils.vis_utils import plot_model
from sklearn.metrics import classification_report
from sklearn.utils import shuffle
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from collections import Counter

import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
from tensorflow.keras.applications.vgg19 import VGG19 , preprocess_input

from tensorflow.keras import Model, layers
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.layers import Dropout,Dense,Input,Conv2D,MaxPooling2D,Flatten,Activation,BatchNormalization
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ffbf94a8f25a> in <cell line: 18>()
#      16
#      17 import tensorflow as tf
# ---> 18 from keras.utils.vis_utils import plot_model
#      19 from sklearn.metrics import classification_report
#      20 from sklearn.utils import shuffle
#
# ModuleNotFoundError: No module named 'keras.utils.vis_utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
root_path = 'D:\\Prionto\\'
labels = []
trainFolder = root_path+'\\Train\\'
testFolder = root_path+'\\Test\\'

quantity_tr = {}
quantity_te = {}
for folder in os.listdir(trainFolder):
    quantity_tr[folder] = len(os.listdir(trainFolder+folder))
    labels.append(folder)

for folder in os.listdir(testFolder):
    quantity_te[folder] = len(os.listdir(testFolder+folder))


quantity_train = pd.DataFrame(list(quantity_tr.items()),
                              index=range(0,len(quantity_tr)), columns=['class','count'])

quantity_test = pd.DataFrame(list(quantity_te.items()),
                              index=range(0,len(quantity_te)), columns=['class','count'])

figure, ax = plt.subplots(1,2,figsize=(12,5))
sns.barplot(x='class',y='count',data=quantity_train,ax=ax[0])
sns.barplot(x='class',y='count',data=quantity_test,ax=ax[1])

print("Number of images in training: ", sum(quantity_tr.values()))
print("Number of images in testing: ", sum(quantity_te.values()))

plt.show()
# Out:
# Number of images in training:  4000
# Number of images in testing:  1200

# %%
img_height = img_width = 128
batch_size = 32
labels
# Out:
# ['healthy', 'unhealthy']

# %%
X_train = []
y_train = []

X_test = []
y_test = []

for i in labels:
    folderPath = os.path.join(root_path,'Train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j), 1)
        img = cv2.resize(img,(img_height, img_width))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join(root_path,'Test',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j), 1)
        img = cv2.resize(img,(img_height, img_width))
        X_test.append(img)
        y_test.append(i)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:11<00:00, 170.80it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:11<00:00, 178.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:05<00:00, 108.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:04<00:00, 135.77it/s]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
print(np.min(X_train), np.max(X_train))
# Out:
# 0 255

# %%
X_train=X_train/255.0
X_test=X_test/255.0

# %%
print(np.min(X_train), np.max(X_train))
# Out:
# 0.0 1.0

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (4000, 128, 128, 3) (4000,)
# (1200, 128, 128, 3) (1200,)

# %%
X_train, y_train = shuffle(X_train, y_train, random_state=0)
X_test, y_test = shuffle(X_test, y_test, random_state=0)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (4000, 128, 128, 3) (4000, 2)
# (1200, 128, 128, 3) (1200, 2)

# %%
train_datagen = ImageDataGenerator(
        fill_mode="nearest",
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        validation_split=0.1
)
test_datagen = ImageDataGenerator()


train_ds = train_datagen.flow(
  X_train, y_train,
  subset="training",
  shuffle=True,
  batch_size=batch_size)

# %%
val_ds = train_datagen.flow(
  X_train, y_train,
  subset="validation",
  shuffle=True,
  batch_size=batch_size)

# %%
test_ds = test_datagen.flow(
  X_test, y_test,
  shuffle=False,
  batch_size=batch_size)

# %%
j = 0
class_mapping = {}
for i in labels:
    class_mapping[j] = i
    j+=1

class_mapping
# Out:
# {0: 'healthy', 1: 'unhealthy'}

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 128, 128, 3)
# (32, 2)

# %%
tf.keras.backend.clear_session()
epoch = 35

# %%
sequential_model = Sequential(
    [
        layers.Conv2D(128, (3, 3), input_shape=(img_height, img_width, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.BatchNormalization(),

        layers.Conv2D(32, (3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.BatchNormalization(),

        layers.Conv2D(64, (3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.BatchNormalization(),

        layers.Conv2D(128, (3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.BatchNormalization(),

        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(2, activation="sigmoid"),
    ]
)

sequential_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 126, 126, 128)     3584
#
#  max_pooling2d_3 (MaxPooling  (None, 63, 63, 128)      0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 63, 63, 128)      512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 61, 61, 32)        36896
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 30, 30, 32)       128
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  batch_normalization_6 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 1,330,722
# Trainable params: 1,330,018
# Non-trainable params: 704
# _________________________________________________________________

# %%
sequential_model.compile(optimizer='adam', loss='binary_crossentropy',metrics=Metrics)

# %%
sequential_model_history = sequential_model.fit(train_ds,
                                epochs = epoch,
                                validation_data = val_ds,
                                callbacks=callbacks,
                                verbose=1)
# Out:
# Epoch 1/35
# 113/113 [==============================] - 60s 525ms/step - loss: 0.3935 - accuracy: 0.8386 - auc: 0.8525 - recall: 0.6604 - precision: 0.8247 - val_loss: 2.2738 - val_accuracy: 0.4925 - val_auc: 0.5491 - val_recall: 0.4925 - val_precision: 0.4925 - lr: 0.0010
# Epoch 2/35
# 113/113 [==============================] - 58s 513ms/step - loss: 0.2633 - accuracy: 0.8883 - auc: 0.9581 - recall: 0.8903 - precision: 0.8834 - val_loss: 1.4646 - val_accuracy: 0.4925 - val_auc: 0.6185 - val_recall: 0.4925 - val_precision: 0.4925 - lr: 0.0010
# Epoch 3/35
# 113/113 [==============================] - 60s 532ms/step - loss: 0.2349 - accuracy: 0.9050 - auc: 0.9666 - recall: 0.9036 - precision: 0.9006 - val_loss: 1.2186 - val_accuracy: 0.4950 - val_auc: 0.6337 - val_recall: 0.4875 - val_precision: 0.5159 - lr: 0.0010
# Epoch 4/35
# 113/113 [==============================] - 58s 513ms/step - loss: 0.1949 - accuracy: 0.9225 - auc: 0.9768 - recall: 0.9233 - precision: 0.9215 - val_loss: 1.9441 - val_accuracy: 0.4925 - val_auc: 0.6550 - val_recall: 0.4925 - val_precision: 0.4925 - lr: 0.0010
# Epoch 5/35
# 113/113 [==============================] - 58s 509ms/step - loss: 0.1707 - accuracy: 0.9361 - auc: 0.9820 - recall: 0.9331 - precision: 0.9338 - val_loss: 0.4359 - val_accuracy: 0.7825 - val_auc: 0.8798 - val_recall: 0.8025 - val_precision: 0.7829 - lr: 0.0010
# Epoch 6/35
# 113/113 [==============================] - 58s 508ms/step - loss: 0.1460 - accuracy: 0.9444 - auc: 0.9866 - recall: 0.9422 - precision: 0.9459 - val_loss: 0.4129 - val_accuracy: 0.8225 - val_auc: 0.9094 - val_recall: 0.8200 - val_precision: 0.8119 - lr: 0.0010
# Epoch 7/35
# 113/113 [==============================] - 58s 509ms/step - loss: 0.1371 - accuracy: 0.9511 - auc: 0.9884 - recall: 0.9483 - precision: 0.9468 - val_loss: 0.6997 - val_accuracy: 0.7500 - val_auc: 0.8649 - val_recall: 0.7550 - val_precision: 0.7569 - lr: 0.0010
# Epoch 8/35
# 113/113 [==============================] - 58s 509ms/step - loss: 0.1292 - accuracy: 0.9506 - auc: 0.9893 - recall: 0.9481 - precision: 0.9528 - val_loss: 0.4272 - val_accuracy: 0.8300 - val_auc: 0.9189 - val_recall: 0.8425 - val_precision: 0.8300 - lr: 0.0010
# Epoch 19/35
# 113/113 [==============================] - 58s 512ms/step - loss: 0.0221 - accuracy: 0.9928 - auc: 0.9997 - recall: 0.9919 - precision: 0.9925 - val_loss: 0.0843 - val_accuracy: 0.9775 - val_auc: 0.9956 - val_recall: 0.9725 - val_precision: 0.9774 - lr: 1.0000e-04
# Epoch 20/35
# 113/113 [==============================] - 58s 511ms/step - loss: 0.0231 - accuracy: 0.9922 - auc: 0.9997 - recall: 0.9919 - precision: 0.9925 - val_loss: 0.0791 - val_accuracy: 0.9825 - val_auc: 0.9959 - val_recall: 0.9825 - val_precision: 0.9850 - lr: 1.0000e-04
# Epoch 21/35
# 113/113 [==============================] - 58s 512ms/step - loss: 0.0135 - accuracy: 0.9953 - auc: 0.9999 - recall: 0.9950 - precision: 0.9969 - val_loss: 0.0844 - val_accuracy: 0.9800 - val_auc: 0.9958 - val_recall: 0.9800 - val_precision: 0.9800 - lr: 1.0000e-04
# Epoch 22/35
# 113/113 [==============================] - 58s 517ms/step - loss: 0.0123 - accuracy: 0.9969 - auc: 0.9999 - recall: 0.9958 - precision: 0.9969 - val_loss: 0.0895 - val_accuracy: 0.9775 - val_auc: 0.9940 - val_recall: 0.9675 - val_precision: 0.9773 - lr: 1.0000e-04
# Epoch 23/35
# 113/113 [==============================] - 59s 518ms/step - loss: 0.0170 - accuracy: 0.9947 - auc: 0.9998 - recall: 0.9944 - precision: 0.9947 - val_loss: 0.0720 - val_accuracy: 0.9775 - val_auc: 0.9962 - val_recall: 0.9750 - val_precision: 0.9774 - lr: 1.0000e-04
# Epoch 24/35
# 113/113 [==============================] - 58s 511ms/step - loss: 0.0158 - accuracy: 0.9950 - auc: 0.9996 - recall: 0.9953 - precision: 0.9936 - val_loss: 0.0881 - val_accuracy: 0.9775 - val_auc: 0.9957 - val_recall: 0.9775 - val_precision: 0.9799 - lr: 1.0000e-04
# Epoch 25/35
# 113/113 [==============================] - 58s 511ms/step - loss: 0.0129 - accuracy: 0.9958 - auc: 0.9998 - recall: 0.9964 - precision: 0.9956 - val_loss: 0.0739 - val_accuracy: 0.9775 - val_auc: 0.9949 - val_recall: 0.9775 - val_precision: 0.9775 - lr: 1.0000e-04
# Epoch 26/35
# 113/113 [==============================] - 58s 511ms/step - loss: 0.0141 - accuracy: 0.9961 - auc: 0.9997 - recall: 0.9958 - precision: 0.9961 - val_loss: 0.0720 - val_accuracy: 0.9850 - val_auc: 0.9949 - val_recall: 0.9825 - val_precision: 0.9850 - lr: 1.0000e-04
# Epoch 27/35
# 113/113 [==============================] - 58s 512ms/step - loss: 0.0099 - accuracy: 0.9964 - auc: 1.0000 - recall: 0.9961 - precision: 0.9964 - val_loss: 0.0809 - val_accuracy: 0.9825 - val_auc: 0.9964 - val_recall: 0.9800 - val_precision: 0.9776 - lr: 1.0000e-04
# Epoch 28/35
# 113/113 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9950 - auc: 0.9999 - recall: 0.9950 - precision: 0.9944
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 113/113 [==============================] - 58s 512ms/step - loss: 0.0136 - accuracy: 0.9950 - auc: 0.9999 - recall: 0.9950 - precision: 0.9944 - val_loss: 0.0810 - val_accuracy: 0.9800 - val_auc: 0.9964 - val_recall: 0.9800 - val_precision: 0.9800 - lr: 1.0000e-04
# Epoch 29/35
# 113/113 [==============================] - 58s 510ms/step - loss: 0.0096 - accuracy: 0.9969 - auc: 1.0000 - recall: 0.9975 - precision: 0.9972 - val_loss: 0.0840 - val_accuracy: 0.9825 - val_auc: 0.9925 - val_recall: 0.9800 - val_precision: 0.9849 - lr: 1.0000e-05
# Epoch 30/35
# 113/113 [==============================] - 58s 511ms/step - loss: 0.0125 - accuracy: 0.9964 - auc: 0.9999 - recall: 0.9956 - precision: 0.9956 - val_loss: 0.0638 - val_accuracy: 0.9875 - val_auc: 0.9967 - val_recall: 0.9850 - val_precision: 0.9875 - lr: 1.0000e-05
# Epoch 31/35
# 113/113 [==============================] - 58s 510ms/step - loss: 0.0111 - accuracy: 0.9964 - auc: 0.9999 - recall: 0.9961 - precision: 0.9969 - val_loss: 0.0683 - val_accuracy: 0.9850 - val_auc: 0.9951 - val_recall: 0.9825 - val_precision: 0.9874 - lr: 1.0000e-05
# Epoch 32/35
# 113/113 [==============================] - 58s 510ms/step - loss: 0.0098 - accuracy: 0.9969 - auc: 1.0000 - recall: 0.9975 - precision: 0.9969 - val_loss: 0.0697 - val_accuracy: 0.9850 - val_auc: 0.9955 - val_recall: 0.9850 - val_precision: 0.9825 - lr: 1.0000e-05
# Epoch 33/35
# 113/113 [==============================] - 58s 509ms/step - loss: 0.0090 - accuracy: 0.9986 - auc: 0.9997 - recall: 0.9986 - precision: 0.9978 - val_loss: 0.0784 - val_accuracy: 0.9775 - val_auc: 0.9963 - val_recall: 0.9775 - val_precision: 0.9751 - lr: 1.0000e-05
# Epoch 34/35
# 113/113 [==============================] - 58s 510ms/step - loss: 0.0090 - accuracy: 0.9972 - auc: 1.0000 - recall: 0.9978 - precision: 0.9972 - val_loss: 0.0609 - val_accuracy: 0.9850 - val_auc: 0.9965 - val_recall: 0.9875 - val_precision: 0.9850 - lr: 1.0000e-05
# Epoch 35/35
# 113/113 [==============================] - 58s 510ms/step - loss: 0.0093 - accuracy: 0.9972 - auc: 1.0000 - recall: 0.9969 - precision: 0.9969 - val_loss: 0.0643 - val_accuracy: 0.9850 - val_auc: 0.9964 - val_recall: 0.9800 - val_precision: 0.9874 - lr: 1.0000e-05

# %%
# plot the loss
plt.plot(sequential_model_history.history['loss'], label='train loss')
plt.plot(sequential_model_history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(sequential_model_history.history['accuracy'], label='train acc')
plt.plot(sequential_model_history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
def calculate_tpr_fpr(y_real, y_pred):



    cm = confusion_matrix(y_real, y_pred)

    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
    TP = cm[1, 1]


    tpr =  TP/(TP + FN)
    fpr = 1 - TN/(TN+FP)

    return tpr, fpr

# %%
labels_pred= sequential_model.predict(test_ds)

# %%
y_pred = tf.argmax(labels_pred, axis=1)
# y_pred

# %%
y_true = tf.argmax(y_test, axis = 1)
# y_true

# %%
print(classification_report(y_true, y_pred, target_names=labels))
ConfusionMatrixDisplay.from_predictions(y_true, y_pred, display_labels=labels)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      healthy       0.92      0.99      0.95       600
#    unhealthy       0.99      0.91      0.95       600
#
#     accuracy                           0.95      1200
#    macro avg       0.95      0.95      0.95      1200
# weighted avg       0.95      0.95      0.95      1200
